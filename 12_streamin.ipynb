# %%
from langgraph.graph import StateGraph, START, END, add_messages
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict, Annotated
from langgraph.checkpoint.memory import MemorySaver
from dotenv import load_dotenv

load_dotenv()

model = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')

class ChatState(TypedDict):
    
    messages: Annotated[list[BaseMessage], add_messages]

def chatbot(state: ChatState) -> ChatState:
    response = model.invoke(state['messages'])
    
    return {'messages': [response.content]}

checkpointer = MemorySaver()
graph = StateGraph(ChatState)

graph.add_node('Chatbot', chatbot)

graph.add_edge(START, 'Chatbot')
graph.add_edge('Chatbot', END)
bot = graph.compile(checkpointer=checkpointer)

# %%
thread_id = '1'
for message_chunk, metadata in bot.stream(

    {'messages': [HumanMessage(content= 'what is jalebi')]},
    config = {'configurable': {'thread_id': thread_id}},
    stream_mode = 'messages'):

    if message_chunk.content:
        print(message_chunk.content, end = '', flush = True)
# Out:
# **Jalebi** is a popular sweet snack or dessert found in India, Pakistan, Bangladesh, Nepal, and parts of the Middle East. It's instantly recognizable by its distinctive pretzel-like or spiral shape and its vibrant orange-yellow color.
#
# Here's a breakdown of what it is:
#
# 1.  **Batter:** It's made from a fermented batter, typically of maida (all-purpose flour) and water, sometimes with a little chickpea flour (besan) or rice flour for extra crispiness. The fermentation is key to its unique texture and slight tang.
# 2.  **Frying:** The batter is squeezed through a piping bag or a special jalebi dispenser directly into hot oil, creating the signature spiral shape. It's deep-fried until golden and crisp.
# 3.  **Syrup Soaking:** Immediately after frying, the hot jalebis are plunged into a warm, fragrant sugar syrup. This syrup is often flavored with cardamom, saffron, or rose water. The hot jalebis rapidly absorb the sweet syrup.
# 4.  **Taste and Texture:**
#     *   **Crispy:** The outside is wonderfully crisp from the frying.
#     *   **Juicy & Syrupy:** The inside is soft, chewy, and completely saturated with sweet syrup.
#     *   **Intensely Sweet:** It's a very sweet dessert, often with aromatic notes from the syrup flavorings.
#     *   **Slight Tang:** The fermented batter can give it a very subtle, pleasant tang that balances the sweetness.
#
# **How it's enjoyed:**
# Jalebi is a beloved street food, often sold by vendors who make it fresh on the spot. It's also a common dessert for festivals (like Diwali), celebrations, and special occasions. It's typically eaten warm, either on its own or sometimes with a glass of milk, rabri (thickened sweet milk), or yogurt to balance the sweetness. In some regions, it's even eaten for breakfast.
#
# The combination of its warm, sugary crunch and its soft, syrup-soaked interior is what makes Jalebi so uniquely appealing.

# %%
bot.get_state(config = {'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='what is jalebi', additional_kwargs={}, response_metadata={}, id='a14583b1-3528-4741-9a9a-70aec21e458f'), HumanMessage(content="**Jalebi** is a popular sweet snack or dessert found in India, Pakistan, Bangladesh, Nepal, and parts of the Middle East. It's instantly recognizable by its distinctive pretzel-like or spiral shape and its vibrant orange-yellow color.\n\nHere's a breakdown of what it is:\n\n1.  **Batter:** It's made from a fermented batter, typically of maida (all-purpose flour) and water, sometimes with a little chickpea flour (besan) or rice flour for extra crispiness. The fermentation is key to its unique texture and slight tang.\n2.  **Frying:** The batter is squeezed through a piping bag or a special jalebi dispenser directly into hot oil, creating the signature spiral shape. It's deep-fried until golden and crisp.\n3.  **Syrup Soaking:** Immediately after frying, the hot jalebis are plunged into a warm, fragrant sugar syrup. This syrup is often flavored with cardamom, saffron, or rose water. The hot jalebis rapidly absorb the sweet syrup.\n4.  **Taste and Texture:**\n    *   **Crispy:** The outside is wonderfully crisp from the frying.\n    *   **Juicy & Syrupy:** The inside is soft, chewy, and completely saturated with sweet syrup.\n    *   **Intensely Sweet:** It's a very sweet dessert, often with aromatic notes from the syrup flavorings.\n    *   **Slight Tang:** The fermented batter can give it a very subtle, pleasant tang that balances the sweetness.\n\n**How it's enjoyed:**\nJalebi is a beloved street food, often sold by vendors who make it fresh on the spot. It's also a common dessert for festivals (like Diwali), celebrations, and special occasions. It's typically eaten warm, either on its own or sometimes with a glass of milk, rabri (thickened sweet milk), or yogurt to balance the sweetness. In some regions, it's even eaten for breakfast.\n\nThe combination of its warm, sugary crunch and its soft, syrup-soaked interior is what makes Jalebi so uniquely appealing.", additional_kwargs={}, response_metadata={}, id='cff1f21c-92b5-4d9b-a899-332c167da48e')]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1885f1-8734-68e8-8001-438bbd359a74'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-25T19:29:03.867517+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1885f1-3fcd-6cdc-8000-3ea4d58a7e8b'}}, tasks=(), interrupts=())
